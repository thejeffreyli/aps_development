# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

import numpy as np
from scipy.sparse import csr_matrix
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import pandas as pd

# %%
#original_image = cv2.imread('/Users/jeffr/Desktop/img.jpg')

path = '/Users/jeffr/Desktop/aps_development/direct_beam/foo.png'
#path = '/Users/jeffr/Desktop/img.jpeg'
img = cv2.imread(path)

print(type(img))
print(img.shape)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# <class 'numpy.ndarray'>
# (217, 108, 3)

# %%
print(type(img_2D))

# %%
# Reshaping the image into a 2D array of pixels and 3 color values (RGB)
pixel_vals = img.reshape((-1,3))
 
# Convert to float type
pixel_vals = np.float32(pixel_vals)

# %%
# criteria for stopping: 100 iterations or 85% accuracy,
criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.85)
 
# random centroids, k clusters
k = 2
retval, labels, centers = cv2.kmeans(pixel_vals, k, None, criteria, 20, cv2.KMEANS_RANDOM_CENTERS)

# convert data into 8-bit values
centers = np.uint8(centers)
segmented_data = centers[labels.flatten()]
    
# reshape data 
segmented_image = segmented_data.reshape((img.shape))


plt.imshow(cv2.cvtColor(segmented_image, cv2.COLOR_BGR2RGB)) 
#plt.gca().invert_yaxis()

# %%
print(centers)
# Out:
# [[133  69  62]
#  [141 120  41]]

# %%
import numpy
a = segmented_image


c = centers[0]
indices = numpy.where(numpy.all(a == c, axis=-1))
#print (indices)

ty = int(sum(indices[0])/len(indices[0]))
tx = int(sum(indices[1])/len(indices[1]))


print(ty,tx)
#w = zip(indices[0], indices[1])

#result_set = set(w)
#print(result_set)
# Out:
# 171 53
